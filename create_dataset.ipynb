# %% [markdown]
# # Создание датасета

# %% [markdown]
# Сначала установлю нужные библиотеки

# %%
# %pip install selenium webdriver-manager bs4 pandas surya-ocr
# Out:
# Requirement already satisfied: selenium in c:\hse\технологическое предпринимательство\project\.venv\lib\site-packages (4.38.0)
# Requirement already satisfied: webdriver-manager in c:\hse\технологическое предпринимательство\project\.venv\lib\site-packages (4.0.2)
# Requirement already satisfied: bs4 in c:\hse\технологическое предпринимательство\project\.venv\lib\site-packages (0.0.2)
# Requirement already satisfied: pandas in c:\hse\технологическое предпринимательство\project\.venv\lib\site-packages (2.3.3)
# Requirement already satisfied: urllib3<3.0,>=2.5.0 in c:\hse\технологическое предпринимательство\project\.venv\lib\site-packages (from urllib3[socks]<3.0,>=2.5.0->selenium) (2.5.0)
# Requirement already satisfied: trio<1.0,>=0.31.0 in c:\hse\технологическое предпринимательство\project\.venv\lib\site-packages (from selenium) (0.32.0)
# Requirement already satisfied: trio-websocket<1.0,>=0.12.2 in c:\hse\технологическое предпринимательство\project\.venv\lib\site-packages (from selenium) (0.12.2)
# Requirement already satisfied: certifi>=2025.10.5 in c:\hse\технологическое предпринимательство\project\.venv\lib\site-packages (from selenium) (2025.11.12)
# Requirement already satisfied: typing_extensions<5.0,>=4.15.0 in c:\hse\технологическое предпринимательство\project\.venv\lib\site-packages (from selenium) (4.15.0)
# Requirement already satisfied: websocket-client<2.0,>=1.8.0 in c:\hse\технологическое предпринимательство\project\.venv\lib\site-packages (from selenium) (1.9.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\hse\технологическое предпринимательство\project\.venv\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (25.4.0)
# Requirement already satisfied: sortedcontainers in c:\hse\технологическое предпринимательство\project\.venv\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\hse\технологическое предпринимательство\project\.venv\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (3.11)
# Requirement already satisfied: outcome in c:\hse\технологическое предпринимательство\project\.venv\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\hse\технологическое предпринимательство\project\.venv\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (1.3.1)
# Requirement already satisfied: cffi>=1.14 in c:\hse\технологическое предпринимательство\project\.venv\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (2.0.0)
# Requirement already satisfied: exceptiongroup in c:\hse\технологическое предпринимательство\project\.venv\lib\site-packages (from trio<1.0,>=0.31.0->selenium) (1.3.1)
# Requirement already satisfied: wsproto>=0.14 in c:\hse\технологическое предпринимательство\project\.venv\lib\site-packages (from trio-websocket<1.0,>=0.12.2->selenium) (1.3.2)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\hse\технологическое предпринимательство\project\.venv\lib\site-packages (from urllib3[socks]<3.0,>=2.5.0->selenium) (1.7.1)
# Requirement already satisfied: requests in c:\hse\технологическое предпринимательство\project\.venv\lib\site-packages (from webdriver-manager) (2.32.5)
# Requirement already satisfied: python-dotenv in c:\hse\технологическое предпринимательство\project\.venv\lib\site-packages (from webdriver-manager) (1.2.1)
# Requirement already satisfied: packaging in c:\hse\технологическое предпринимательство\project\.venv\lib\site-packages (from webdriver-manager) (25.0)
# Requirement already satisfied: beautifulsoup4 in c:\hse\технологическое предпринимательство\project\.venv\lib\site-packages (from bs4) (4.14.3)
# Requirement already satisfied: numpy>=1.22.4 in c:\hse\технологическое предпринимательство\project\.venv\lib\site-packages (from pandas) (2.2.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\hse\технологическое предпринимательство\project\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\hse\технологическое предпринимательство\project\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\hse\технологическое предпринимательство\project\.venv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: pycparser in c:\hse\технологическое предпринимательство\project\.venv\lib\site-packages (from cffi>=1.14->trio<1.0,>=0.31.0->selenium) (2.23)
# Requirement already satisfied: six>=1.5 in c:\hse\технологическое предпринимательство\project\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: h11<1,>=0.16.0 in c:\hse\технологическое предпринимательство\project\.venv\lib\site-packages (from wsproto>=0.14->trio-websocket<1.0,>=0.12.2->selenium) (0.16.0)
# Requirement already satisfied: soupsieve>=1.6.1 in c:\hse\технологическое предпринимательство\project\.venv\lib\site-packages (from beautifulsoup4->bs4) (2.8)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\hse\технологическое предпринимательство\project\.venv\lib\site-packages (from requests->webdriver-manager) (3.4.4)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Импортирую зависимости

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import time

import os
import time
import re
import pandas as pd
import json

import base64
from bs4 import BeautifulSoup

# %% [markdown]
# Код далее инициализирует Selenium WebDriver для Chrome с автоматической загрузкой драйвера, открывает каталог задач ЕГЭ по математике. Кроме того задаются увеличенные таймауты.

# %%
# --- Настройки ---
chrome_options = Options()
chrome_options.add_argument("--start-maximized")
service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service, options=chrome_options)

# --- Открываем страницу и настраиваем драйвер  ---
url = "https://mathb-ege.sdamgia.ru/prob-catalog"
driver.get(url)
driver.set_page_load_timeout(2000)
driver.command_executor.set_timeout(2000)
# Out:
# C:\Users\Марина\AppData\Local\Temp\ipykernel_18712\381732346.py:11: DeprecationWarning: set_timeout() in RemoteConnection is deprecated, set timeout in client_config instead
#   driver.command_executor.set_timeout(2000)

# %% [markdown]
# Функции ниже представляют собой скрипт для автоматизированного скачивания заданий и решений с сайта sdamgia.ru. Он загружает страницы с задачами ЕГЭ по математике, включает отображение решений, извлекает все изображения (формулы и графики) и сохраняет их локально, используя разные методы для Tex-формул (скриншоты) и обычных изображений (JavaScript Canvas).
#
#
# **domain** - массив используемых префиксов сайта - отдельно для профильной и базовой математики.
#
# **Функции ниже:**
#
# 1. `safe_filename(name)`
# **Аргументы:** `name` (str) - исходная URL
# **Возвращает:** str - безопасное имя файла
# **Описание:** Заменяет недопустимые символы в именах файлов на подчеркивания, удаляет префикс https://
#
# 2. `safe_get(driver, url, retries=3)`
# **Аргументы:**
# - `driver` - экземпляр Selenium WebDriver
# - `url` (str) - URL для загрузки
# - `retries` (int) - количество попыток при ошибке (по умолчанию 3)
# **Возвращает:** bool - успех загрузки
# **Описание:** Безопасная загрузка страницы с повторными попытками при ошибках
#
# 3. `ensure_element_visible(driver, element)`
# **Аргументы:**
# - `driver` - экземпляр WebDriver
# - `element` - элемент Selenium
# **Возвращает:** bool - успех прокрутки
# **Описание:** Прокручивает страницу так, чтобы элемент был полностью виден в окне браузера
#
# 4. `download_via_javascript(driver, img_element, filepath)`
# **Аргументы:**
# - `driver` - экземпляр WebDriver
# - `img_element` - элемент изображения
# - `filepath` (str) - путь для сохранения файла
# **Возвращает:** bool - успех скачивания
# **Описание:** Скачивает изображение через JavaScript Canvas API
#
# 5. `extract_images_from_blocks(driver)`
# **Аргументы:** `driver` - экземпляр WebDriver
# **Возвращает:** list - список элементов изображений
# **Описание:** Извлекает все изображения из блоков задач (условия и решения) на странице
#
# 6. `enable_solutions_checkbox(driver)`
# **Аргументы:** `driver` - экземпляр WebDriver
# **Возвращает:** bool - успех включения
# **Описание:** Включает чекбокс "Показать решения" на странице sdamgia.ru
#
# 7. `check_not_visible(element)`
# **Аргументы:** `element` - элемент BeautifulSoup
# **Возвращает:** bool - является ли элемент невидимым
# **Описание:** Проверяет, содержит ли элемент классы или стили, указывающие на скрытость
#
# 8. `check_all_images_in_file(path, url)`
# **Аргументы:**
# - `path` (str) - путь к HTML файлу
# - `url` (str) - исходный URL страницы
# **Возвращает:** bool - все ли изображения скачаны
# **Описание:** Проверяет в сохраненном HTML файле, скачаны ли все изображения
#
# 9. `download_extracted_images(driver, save_dir="images")`
# **Аргументы:**
# - `driver` - экземпляр WebDriver
# - `save_dir` (str) - директория для сохранения (по умолчанию "images")
# **Возвращает:** None (печатает статистику)
# **Описание:** Основная функция скачивания картинок - включает отображение решений, извлекает и скачивает все изображения
#
# 10. `download_page(driver, url, save_dir="pages", wait=3, load_imgs=False)`
# **Аргументы:**
# - `driver` - экземпляр WebDriver
# - `url` (str) - URL страницы
# - `save_dir` (str) - директория для HTML (по умолчанию "pages")
# - `wait` (int) - время ожидания после загрузки (по умолчанию 3 сек)
# - `load_imgs` (bool) - скачивать ли изображения (по умолчанию False)
# **Возвращает:** str или None - путь к сохраненному файлу
# **Описание:** Полный пайплайн - загружает страницу, сохраняет HTML, при необходимости скачивает изображения

# %%
domain = [
    "https://mathb-ege.sdamgia.ru",
    "https://math-ege.sdamgia.ru"
]

def safe_filename(name): 
    # заменяем все недопустимые символы на _
    return re.sub(r'[<>:"/\\|?*&=.]+', '_', name.replace("https://", ""))

def safe_get(driver, url, retries=3):
    for attempt in range(1, retries+1):
        try:
            driver.get(url)
            return True
        except KeyboardInterrupt:
            print("\n[STOP] Остановка по Ctrl+C.")
            raise 
        except Exception as e:
            print(f"[WARN] Ошибка загрузки (попытка {attempt}/{retries}): {e}")
            time.sleep(3)
    return False

def ensure_element_visible(driver, element):
    """Прокручивает к элементу и делает его полностью видимым."""
    try:
        # Прокручиваем к элементу с центрированием
        driver.execute_script("""
            var element = arguments[0];
            var elementRect = element.getBoundingClientRect();
            var absoluteElementTop = elementRect.top + window.pageYOffset;
            var absoluteElementBottom = elementRect.bottom + window.pageYOffset;
            var middle = absoluteElementTop + (elementRect.height / 2);
            
            // Прокручиваем к середине элемента
            window.scrollTo({
                top: middle - (window.innerHeight / 2),
                behavior: 'smooth'
            });
            
            // Даем время на прокрутку
            return new Promise(resolve => setTimeout(resolve, 500));
        """, element)
        
        # Ждем прокрутки
        time.sleep(0.5)
        
        # Дополнительная проверка видимости
        is_visible = driver.execute_script("""
            var elem = arguments[0];
            var rect = elem.getBoundingClientRect();
            
            // Проверяем, что элемент полностью в видимой области
            return (
                rect.top >= 0 &&
                rect.left >= 0 &&
                rect.bottom <= (window.innerHeight || document.documentElement.clientHeight) &&
                rect.right <= (window.innerWidth || document.documentElement.clientWidth)
            );
        """, element)
        
        if not is_visible:
            # Если не полностью видно, прокручиваем еще
            driver.execute_script("arguments[0].scrollIntoView({block: 'center', inline: 'center', behavior: 'smooth'});", element)
            time.sleep(1)
        
        return True
    
    except Exception as e:
        print(f"Ошибка прокрутки: {e}")
        return False
    
def download_via_javascript(driver, img_element, filepath):
    """Скачивает изображение через JavaScript."""
    try:
        script = """
        var callback = arguments[arguments.length - 1];
        var img = arguments[0];
        
        // Создаем новое изображение
        var newImg = new Image();
        newImg.crossOrigin = 'anonymous';
        newImg.src = img.src || img.currentSrc || img.getAttribute('data-src');
        
        newImg.onload = function() {
            var canvas = document.createElement('canvas');
            canvas.width = this.naturalWidth;
            canvas.height = this.naturalHeight;
            
            var ctx = canvas.getContext('2d');
            ctx.drawImage(this, 0, 0);
            
            try {
                var dataUrl = canvas.toDataURL('image/png');
                callback({success: true, dataUrl: dataUrl});
            } catch(e) {
                callback({success: false, error: 'Canvas error: ' + e});
            }
        };
        
        newImg.onerror = function() {
            callback({success: false, error: 'Image load error'});
        };
        
        // Таймаут
        setTimeout(() => callback({success: false, error: 'Timeout'}), 5000);
        """
        
        result = driver.execute_async_script(script, img_element)
        
        if result.get('success'):
            data_url = result['dataUrl']
            if data_url.startswith('data:image/png;base64,'):
                img_data = base64.b64decode(data_url.split('base64,')[1])
                with open(filepath, 'wb') as f:
                    f.write(img_data)
                return True
        elif result.get('error') != 'Image load error':
            print(f"    JS error: {result.get('error')}")
            
    except Exception as e:
        print(f"    JS exception: {e}")
    
    return False

def extract_images_from_blocks(driver):
    """Извлекает картинки из блоков prob_maindiv."""
    blocks = driver.find_elements(By.CLASS_NAME, "prob_maindiv")
    images = []
    
    for block in blocks:
        try:
            # Изображения из условия
            pbody = block.find_element(By.CLASS_NAME, "pbody")
            images += pbody.find_elements(By.TAG_NAME, "img")
            
            # Изображения из решения
            solution = block.find_element(By.CLASS_NAME, "solution")
            images += solution.find_elements(By.TAG_NAME, "img")
            
        except Exception as e:
            print(f"Ошибка обработки блока: {e}")
    
    return images

def enable_solutions_checkbox(driver):
    """Включает галочку через Selenium поиск."""
    try:        
        # Ищем чекбокс по id
        checkbox = driver.find_element(By.ID, "cb_sol")
        
        if not checkbox.is_selected():
            # Кликаем на сам чекбокс
            checkbox.click()
            time.sleep(1)  # ждем применения
            return True
        else:
            return True
            
    except Exception as e:
        print(f"✗ Не удалось найти чекбокс по id='cb_sol': {e}")
        return False

def check_not_visible(element):
    if "solution" in element.get("class", ''):
        return False
    return ('wtooltip' in element.get('class', '')) or bool(re.search(r'display\s*:\s*none', element.get("style", ''), re.IGNORECASE))

def check_all_images_in_file(path, url):
    """Проверяет что все картинки из файла загружены"""
    with open(path, encoding="utf-8") as f:
        soup = BeautifulSoup(f.read(), "html")

    images = []

    for block in soup.find_all("div", class_="prob_maindiv"):

        for element in block.find_all(check_not_visible):
            element.decompose()
        # тело условия
        images += block.find("div", class_="pbody").find_all("img")
        # решение
        images += block.find("div", class_="solution").find_all("img")

    for img in images:
        if 'display: none' in img.get("styles", ''):
            continue
        src = img.get("src")
        is_tex = "tex" in img.get("class", '')

        if src.startswith('/'):
            if url.startswith(domain[0]):
                src = domain[0] + src
            elif url.startswith(domain[1]):
                src = domain[1] + src
            else:
                print(f"ERROR: неизвестный домен url {url}")
        filename = f"{safe_filename(src)}.png"
        img_path = os.path.join("images", filename)
        if is_tex:
            img_path = os.path.join(os.path.join("images", "tex"), filename)
        if not os.path.exists(img_path):
            return False
    return True

def download_extracted_images(driver, save_dir="images"):
    """Скачивает извлеченные картинки."""
    enable_solutions_checkbox(driver)
    images_data = extract_images_from_blocks(driver)
    os.makedirs(save_dir, exist_ok=True)
    save_dir_tex = os.path.join(save_dir, 'tex')
    os.makedirs(save_dir_tex, exist_ok=True)
    downloaded = 0
    for i, img in enumerate(images_data):
        try:
            src = img.get_attribute("src") or ""
            if not src:
                print("WARNING: нет src в картинке")
                continue
            if not img.is_displayed():
                continue
            
            # Создаем имя файла
            classes = img.get_attribute("class") or ""
            has_tex_class = "tex" in classes.lower()

            filename = safe_filename(src)
            filename = f"{filename}.png"
            filepath = os.path.join(save_dir, filename)
            if has_tex_class:
                filepath = os.path.join(save_dir_tex, filename)
            
            # Пропускаем если уже существует
            if os.path.exists(filepath) and os.path.getsize(filepath) > 0:
                downloaded += 1
                continue
            
            # Скачиваем            
            if has_tex_class:
                if not ensure_element_visible(driver, img):
                    print(f"WARNING: не видно изображение {filename}")
                img.screenshot(filepath)
            else:
                if not download_via_javascript(driver, img, filepath):
                    if not ensure_element_visible(driver, img):
                        print(f"WARNING: не видно изображение {filename}")
                    img.screenshot(filepath)
            
            if os.path.exists(filepath):
                downloaded += 1
                
        except Exception as e:
            print(f"  ✗ Ошибка: {e}")
    print(f"Скачано {downloaded} из {len(images_data)} изображений")

def download_page(driver, url, save_dir="pages", wait=3, load_imgs=False):
    """Скачивает страницу через уже существующий драйвер, если её ещё нет."""

    os.makedirs(save_dir, exist_ok=True)

    # имя файла из URL
    fname = safe_filename(url) + ".html"
    path = os.path.join(save_dir, fname)

    if os.path.exists(path) and (not load_imgs or check_all_images_in_file(path, url)):
        print(f"Файл уже существует: {path}")
        return path

    print(f"Скачиваю страницу {url} ...")
    ok = safe_get(driver, url)
    if not ok:
        print(f"[FAIL] Не удалось загрузить страницу: {url}")
        return None
    time.sleep(wait)

    html = driver.page_source
    with open(path, "w", encoding="utf-8") as f:
        f.write(html)

    print(f"Сохранено: {path}")

    if load_imgs:
        download_extracted_images(driver)
        
    return path

# %% [markdown]
# Скачаваю каталоги заданий по темам для базоваого и профильного уровня математики.

# %%
_ = download_page(driver, "https://mathb-ege.sdamgia.ru/prob-catalog")
_ = download_page(driver, "https://math-ege.sdamgia.ru/prob-catalog")
# Out:
# Файл уже существует: pages\mathb-ege_sdamgia_ru_prob-catalog.html
# Файл уже существует: pages\math-ege_sdamgia_ru_prob-catalog.html

# %% [markdown]
# Ячейка ниже содержит функции для парсинга каталога задач с сайта sdamgia.ru. Код обрабатывает сохраненные HTML-страницы каталога, извлекает структуру категорий и подкатегорий задач, очищает текст от форматирования и формирует таблицу с информацией о темах, количестве задач и ссылками для дальнейшей обработки.
#
# **Функции:**
#
# 1. `clean_text(text)`
# **Аргументы:** `text` (str) - исходный текст
# **Возвращает:** str - очищенный текст
# **Описание:** Удаляет мягкие переносы и лишние пробелы, оставляя только один пробел между словами.
#
# 2. `strip_leading_number(text)`
# **Аргументы:** `text` (str) - текст с возможным номером в начале
# **Возвращает:** str - текст без ведущего номера
# **Описание:** Удаляет шаблоны вида "число. " в начале строки.
#
# 3. `parse_catalog(html_path)`
# **Аргументы:** `html_path` (str) - путь к сохраненному HTML-файлу каталога
# **Возвращает:** pandas.DataFrame - таблица с колонками: category, subcategory, link, count
# **Описание:** Парсит структуру каталога задач, извлекает категории и подкатегории, проверяет соответствие количества задач, возвращает структурированные данные для дальнейшей обработки.

# %%
def clean_text(text):
    if not text:
        return text
    # убираем мягкие переносы и лишние пробелы
    text = text.replace("\xad", "")
    return re.sub(r"\s+", " ", text).strip()

def strip_leading_number(text):
    # убирает "1. " или "12. " в начале
    return re.sub(r'^\s*\d+\.\s*', '', text)

def parse_catalog(html_path):
    """
    Возвращает DataFrame с колонками: category, subcategory, link
    (берёт только главные блоки div.Theme.nobg как категории)
    """
    if not os.path.exists(html_path):
        raise FileNotFoundError(html_path)

    with open(html_path, "r", encoding="utf-8") as f:
        soup = BeautifulSoup(f.read(), "html")

    rows = []

    # только главные категории
    for cat_div in soup.select("div.Theme.nobg"):
        # Надёжно достаём всю надпись внутри span.Theme-title
        title_span = cat_div.select_one("span.Theme-title")
        raw_cat = title_span.get_text(" ", strip=True) if title_span else ""
        raw_cat = clean_text(raw_cat)
        cat_name = strip_leading_number(raw_cat)

        # количество задач у категории
        cat_count_tag = cat_div.select_one("span.Counter.Counter")
        cat_count = int(cat_count_tag.text.strip()) if cat_count_tag else None

        # главная ссылка (на "Перейти" у категории)
        cat_link_tag = cat_div.select_one("a.Theme-link")
        cat_link = cat_link_tag.get("href") if cat_link_tag else None

        # дети (подкатегории) — только те, что внутри Theme-children
        children_div = cat_div.select_one("div.Theme-children")
        sub_counts = []
        if children_div:
            for sub in children_div.select("div.Theme"):
                # подкатегория обычно в a.Theme-titlenot
                sub_name_tag = sub.select_one("a.Theme-titlenot")
                # но на всякий случай fallback на span.Theme-title внутри
                if not sub_name_tag:
                    sub_name_tag = sub.select_one("span.Theme-title")
                sub_name = clean_text(sub_name_tag.get_text(" ", strip=True)) if sub_name_tag else None

                sub_link_tag = sub.select_one("a.Theme-link")
                sub_link = sub_link_tag.get("href") if sub_link_tag else None

                sub_count_tag = sub.select_one("span.Counter.Counter")
                sub_count = int(sub_count_tag.text.strip()) if sub_count_tag else None
                sub_counts.append(sub_count)
                
                rows.append({
                    "category": cat_name,
                    "subcategory": sub_name,
                    "link": sub_link,
                    "count": sub_count
                })

            # проверка: сумма подкатегорий == count категории
            sum_sub = sum(sub_counts)
            if cat_count is not None and sum_sub != cat_count:
                print(f"[WARN] Несовпадение count для категории '{cat_name}': {cat_count} != сумма подкатегорий {sum_sub}")
        else:
            # категория без подкатегорий — записываем саму категорию
            rows.append({
                "category": cat_name,
                "subcategory": None,
                "link": cat_link,
                "count": cat_count
            })

    return pd.DataFrame(rows)

# %% [markdown]
# Провожу парсинг каталогов задач для профильного и базового уровня, формирую общий датасет с дополнительной колонкой profile и сохраняю его.

# %%
files = [
    ("pages\math-ege_sdamgia_ru_prob-catalog.html", "profile"),
    ("pages\mathb-ege_sdamgia_ru_prob-catalog.html", "basic")
]
df_list = []

for file_path, profile_type in files:
    df = parse_catalog(file_path)
    df['profile'] = profile_type
    df_list.append(df)

# объединяем
all_df = pd.concat(df_list, ignore_index=True)

# сохраняем в CSV
all_df.to_csv("ege_categories.csv", encoding="utf-8")

print("Готово! CSV создан: ege_categories.csv")
# Out:
# Готово! CSV создан: ege_categories.csv

# %% [markdown]
# Код ниже реализует пайплайн массового скачивания страниц с задачами из подготовленного каталога. Он использует предварительно собранную таблицу категорий, формирует правильные URL для версий "print" (без лишних элементов интерфейса) и последовательно загружает все страницы, сохраняя HTML и при необходимости изображения.
#
# **Функции и переменные:**
#
# 1. Константа `BASE_URLS`
# **Тип:** dict
# **Описание:** Словарь с базовыми URL двух версий сайта ЕГЭ по математике: профильный и базовый уровень.
#
# 2. Функция `download_all_print_pages(driver, df, save_dir="pages", load_imgs=False)`
# **Аргументы:**
# - `driver` - экземпляр Selenium WebDriver для управления браузером
# - `df` (DataFrame) - таблица с категориями задач для скачивания
# - `save_dir` (str) - директория для сохранения HTML страниц (по умолчанию "pages")
# - `load_imgs` (bool) - флаг скачивания изображений (по умолчанию False)
#
# **Возвращает:** pandas.DataFrame - обновленная таблица с путями к сохраненным файлам и статусами загрузки
#
# **Описание:**
# Основная функция массового скачивания, которая:
# 1. Добавляет в таблицу служебные колонки для отслеживания прогресса
# 2. Для каждой строки таблицы формирует URL в формате "print" (упрощенная версия для печати)
# 3. Вызывает функцию `download_page` для загрузки и сохранения страницы
# 4. Обновляет таблицу путями к сохраненным файлам и статусом скачивания изображений
# 5. Выводит прогресс в консоль (номер текущей страницы из общего количества)

# %%
BASE_URLS = {
    "profile": "https://math-ege.sdamgia.ru",
    "basic":     "https://mathb-ege.sdamgia.ru"
}

def download_all_print_pages(driver, df, save_dir="pages", load_imgs=False):
    if 'file' not in df.columns:
        df['file'] = None
    if 'downloaded_imgs' not in df.columns:
        df['downloaded_imgs'] = False

    for idx, row in df.iterrows():
        print(f"{idx + 1}/{len(df)}")
        base_url = BASE_URLS[row["profile"]]
        
        # ссылка из таблицы
        link = row["link"]
        
        # добавляем print=true корректно
        if "print=true" in link:
            link_print = link
        elif "?" in link:
            link_print = link + "&print=true"
        else:
            link_print = link + "?print=true"

        full_url = base_url + link_print

        save_path = download_page(driver, full_url, save_dir, load_imgs=load_imgs and not df.loc[idx, 'downloaded_imgs'])

        df.loc[idx, 'file'] = save_path
        df.loc[idx, 'downloaded_imgs'] = load_imgs or df.loc[idx, 'downloaded_imgs']

    return df

# %% [markdown]
# Скачаваю все страницы и изображения с них и сохраняю итоговый датасет.

# %%
all_df = download_all_print_pages(driver, all_df, load_imgs=True)
# сохраняем в CSV
all_df.to_csv("ege_categories.csv", encoding="utf-8")
# Out:
# 1/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_79_filter_all_print_true.html
# 2/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_90_filter_all_print_true.html
# 3/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_96_filter_all_print_true.html
# 4/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_102_filter_all_print_true.html
# 5/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_94_filter_all_print_true.html
# 6/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_111_filter_all_print_true.html
# 7/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_112_filter_all_print_true.html
# 8/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_113_filter_all_print_true.html
# 9/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_114_filter_all_print_true.html
# 10/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_182_filter_all_print_true.html
# 11/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_192_filter_all_print_true.html
# 12/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_193_filter_all_print_true.html
# 13/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_180_filter_all_print_true.html
# 14/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_148_filter_all_print_true.html
# 15/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_140_filter_all_print_true.html
# 16/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_178_filter_all_print_true.html
# 17/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_177_filter_all_print_true.html
# 18/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_197_filter_all_print_true.html
# 19/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_194_filter_all_print_true.html
# 20/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_144_filter_all_print_true.html
# 21/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_151_filter_all_print_true.html
# 22/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_166_filter_all_print_true.html
# 23/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_185_filter_all_print_true.html
# 24/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_265_filter_all_print_true.html
# 25/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_14_filter_all_print_true.html
# 26/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_9_filter_all_print_true.html
# 27/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_10_filter_all_print_true.html
# 28/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_11_filter_all_print_true.html
# 29/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_12_filter_all_print_true.html
# 30/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_13_filter_all_print_true.html
# 31/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_55_filter_all_print_true.html
# 32/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_60_filter_all_print_true.html
# 33/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_57_filter_all_print_true.html
# 34/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_62_filter_all_print_true.html
# 35/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_56_filter_all_print_true.html
# 36/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_61_filter_all_print_true.html
# 37/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_58_filter_all_print_true.html
# 38/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_63_filter_all_print_true.html
# 39/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_65_filter_all_print_true.html
# 40/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_59_filter_all_print_true.html
# 41/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_64_filter_all_print_true.html
# 42/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_69_filter_all_print_true.html
# 43/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_68_filter_all_print_true.html
# 44/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_70_filter_all_print_true.html
# 45/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_183_filter_all_print_true.html
# 46/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_71_filter_all_print_true.html
# 47/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_72_filter_all_print_true.html
# 48/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_76_filter_all_print_true.html
# 49/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_77_filter_all_print_true.html
# 50/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_73_filter_all_print_true.html
# 51/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_74_filter_all_print_true.html
# 52/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_75_filter_all_print_true.html
# 53/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_184_filter_all_print_true.html
# 54/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_88_filter_all_print_true.html
# 55/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_84_filter_all_print_true.html
# 56/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_85_filter_all_print_true.html
# 57/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_86_filter_all_print_true.html
# 58/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_87_filter_all_print_true.html
# 59/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_89_filter_all_print_true.html
# 60/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_267_filter_all_print_true.html
# 61/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_294_filter_all_print_true.html
# 62/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_125_filter_all_print_true.html
# 63/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_122_filter_all_print_true.html
# 64/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_272_filter_all_print_true.html
# 65/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_191_filter_all_print_true.html
# 66/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_296_filter_all_print_true.html
# 67/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_175_filter_all_print_true.html
# 68/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_81_filter_all_print_true.html
# 69/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_83_filter_all_print_true.html
# 70/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_82_filter_all_print_true.html
# 71/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_80_filter_all_print_true.html
# 72/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_78_filter_all_print_true.html
# 73/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_330_filter_all_print_true.html
# 74/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_290_filter_all_print_true.html
# 75/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_275_filter_all_print_true.html
# 76/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_186_filter_all_print_true.html
# 77/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_167_filter_all_print_true.html
# 78/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_302_filter_all_print_true.html
# 79/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_291_filter_all_print_true.html
# 80/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_202_filter_all_print_true.html
# 81/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_306_filter_all_print_true.html
# 82/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_201_filter_all_print_true.html
# 83/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_303_filter_all_print_true.html
# 84/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_304_filter_all_print_true.html
# 85/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_305_filter_all_print_true.html
# 86/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_280_filter_all_print_true.html
# 87/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_281_filter_all_print_true.html
# 88/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_307_filter_all_print_true.html
# 89/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_282_filter_all_print_true.html
# 90/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_308_filter_all_print_true.html
# 91/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_309_filter_all_print_true.html
# 92/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_283_filter_all_print_true.html
# 93/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_311_filter_all_print_true.html
# 94/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_284_filter_all_print_true.html
# 95/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_285_filter_all_print_true.html
# 96/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_257_filter_all_print_true.html
# 97/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_310_filter_all_print_true.html
# 98/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_206_filter_all_print_true.html
# 99/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_331_filter_all_print_true.html
# 100/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_243_filter_all_print_true.html
# 101/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_242_filter_all_print_true.html
# 102/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_237_filter_all_print_true.html
# 103/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_320_filter_all_print_true.html
# 104/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_238_filter_all_print_true.html
# 105/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_318_filter_all_print_true.html
# 106/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_239_filter_all_print_true.html
# 107/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_313_filter_all_print_true.html
# 108/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_319_filter_all_print_true.html
# 109/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_315_filter_all_print_true.html
# 110/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_245_filter_all_print_true.html
# 111/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_314_filter_all_print_true.html
# 112/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_316_filter_all_print_true.html
# 113/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_244_filter_all_print_true.html
# 114/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_317_filter_all_print_true.html
# 115/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_293_filter_all_print_true.html
# 116/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_292_filter_all_print_true.html
# 117/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_247_filter_all_print_true.html
# 118/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_221_filter_all_print_true.html
# 119/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_276_filter_all_print_true.html
# 120/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_321_filter_all_print_true.html
# 121/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_277_filter_all_print_true.html
# 122/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_278_filter_all_print_true.html
# 123/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_322_filter_all_print_true.html
# 124/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_323_filter_all_print_true.html
# 125/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_279_filter_all_print_true.html
# 126/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_325_filter_all_print_true.html
# 127/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_326_filter_all_print_true.html
# 128/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_324_filter_all_print_true.html
# 129/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_171_filter_all_print_true.html
# 130/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_328_filter_all_print_true.html
# 131/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_327_filter_all_print_true.html
# 132/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_270_filter_all_print_true.html
# 133/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_268_filter_all_print_true.html
# 134/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_207_filter_all_print_true.html
# 135/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_273_filter_all_print_true.html
# 136/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_208_filter_all_print_true.html
# 137/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_274_filter_all_print_true.html
# 138/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_329_filter_all_print_true.html
# 139/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_271_filter_all_print_true.html
# 140/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_266_filter_all_print_true.html
# 141/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_269_filter_all_print_true.html
# 142/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_235_filter_all_print_true.html
# 143/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_172_filter_all_print_true.html
# 144/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_217_filter_all_print_true.html
# 145/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_209_filter_all_print_true.html
# 146/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_210_filter_all_print_true.html
# 147/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_6_filter_all_print_true.html
# 148/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_8_filter_all_print_true.html
# 149/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_7_filter_all_print_true.html
# 150/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_174_filter_all_print_true.html
# 151/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_1_filter_all_print_true.html
# 152/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_2_filter_all_print_true.html
# 153/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_249_filter_all_print_true.html
# 154/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_5_filter_all_print_true.html
# 155/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_54_filter_all_print_true.html
# 156/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_53_filter_all_print_true.html
# 157/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_173_filter_all_print_true.html
# 158/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_252_filter_all_print_true.html
# 159/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_190_filter_all_print_true.html
# 160/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_123_filter_all_print_true.html
# 161/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_181_filter_all_print_true.html
# 162/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_120_filter_all_print_true.html
# 163/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_250_filter_all_print_true.html
# 164/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_127_filter_all_print_true.html
# 165/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_124_filter_all_print_true.html
# 166/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_253_filter_all_print_true.html
# 167/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_126_filter_all_print_true.html
# 168/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_254_filter_all_print_true.html
# 169/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_255_filter_all_print_true.html
# 170/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_256_filter_all_print_true.html
# 171/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_251_filter_all_print_true.html
# 172/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_248_filter_all_print_true.html
# 173/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_295_filter_all_print_true.html
# 174/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_203_filter_all_print_true.html
# 175/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_219_filter_all_print_true.html
# 176/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_220_filter_all_print_true.html
# 177/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_218_filter_all_print_true.html
# 178/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_231_filter_all_print_true.html
# 179/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_230_filter_all_print_true.html
# 180/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_297_filter_all_print_true.html
# 181/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_298_filter_all_print_true.html
# 182/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_211_filter_all_print_true.html
# 183/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_299_filter_all_print_true.html
# 184/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_169_filter_all_print_true.html
# 185/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_204_filter_all_print_true.html
# 186/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_214_filter_all_print_true.html
# 187/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_246_filter_all_print_true.html
# 188/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_223_filter_all_print_true.html
# 189/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_224_filter_all_print_true.html
# 190/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_225_filter_all_print_true.html
# 191/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_205_filter_all_print_true.html
# 192/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_170_filter_all_print_true.html
# 193/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_215_filter_all_print_true.html
# 194/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_216_filter_all_print_true.html
# 195/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_262_filter_all_print_true.html
# 196/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_260_filter_all_print_true.html
# 197/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_261_filter_all_print_true.html
# 198/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_259_filter_all_print_true.html
# 199/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_232_filter_all_print_true.html
# 200/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_258_filter_all_print_true.html
# 201/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_240_filter_all_print_true.html
# 202/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_241_filter_all_print_true.html
# 203/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_288_filter_all_print_true.html
# 204/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_289_filter_all_print_true.html
# 205/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_286_filter_all_print_true.html
# 206/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_287_filter_all_print_true.html
# 207/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_226_filter_all_print_true.html
# 208/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_227_filter_all_print_true.html
# 209/372
# Файл уже существует: pages\math-ege_sdamgia_ru_test_category_id_228_filter_all_print_true.html
# 210/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_1_filter_all_print_true.html
# 211/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_2_filter_all_print_true.html
# 212/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_174_filter_all_print_true.html
# 213/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_246_filter_all_print_true.html
# 214/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_233_filter_all_print_true.html
# 215/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_244_filter_all_print_true.html
# 216/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_247_filter_all_print_true.html
# 217/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_245_filter_all_print_true.html
# 218/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_248_filter_all_print_true.html
# 219/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_6_filter_all_print_true.html
# 220/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_8_filter_all_print_true.html
# 221/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_291_filter_all_print_true.html
# 222/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_290_filter_all_print_true.html
# 223/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_187_filter_all_print_true.html
# 224/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_166_filter_all_print_true.html
# 225/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_185_filter_all_print_true.html
# 226/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_231_filter_all_print_true.html
# 227/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_54_filter_all_print_true.html
# 228/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_53_filter_all_print_true.html
# 229/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_173_filter_all_print_true.html
# 230/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_292_filter_all_print_true.html
# 231/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_189_filter_all_print_true.html
# 232/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_222_filter_all_print_true.html
# 233/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_255_filter_all_print_true.html
# 234/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_234_filter_all_print_true.html
# 235/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_284_filter_all_print_true.html
# 236/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_286_filter_all_print_true.html
# 237/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_285_filter_all_print_true.html
# 238/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_122_filter_all_print_true.html
# 239/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_301_filter_all_print_true.html
# 240/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_295_filter_all_print_true.html
# 241/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_296_filter_all_print_true.html
# 242/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_293_filter_all_print_true.html
# 243/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_294_filter_all_print_true.html
# 244/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_188_filter_all_print_true.html
# 245/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_253_filter_all_print_true.html
# 246/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_249_filter_all_print_true.html
# 247/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_250_filter_all_print_true.html
# 248/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_251_filter_all_print_true.html
# 249/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_252_filter_all_print_true.html
# 250/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_148_filter_all_print_true.html
# 251/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_140_filter_all_print_true.html
# 252/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_289_filter_all_print_true.html
# 253/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_120_filter_all_print_true.html
# 254/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_288_filter_all_print_true.html
# 255/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_275_filter_all_print_true.html
# 256/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_287_filter_all_print_true.html
# 257/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_263_filter_all_print_true.html
# 258/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_264_filter_all_print_true.html
# 259/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_267_filter_all_print_true.html
# 260/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_265_filter_all_print_true.html
# 261/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_266_filter_all_print_true.html
# 262/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_262_filter_all_print_true.html
# 263/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_297_filter_all_print_true.html
# 264/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_298_filter_all_print_true.html
# 265/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_55_filter_all_print_true.html
# 266/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_5_filter_all_print_true.html
# 267/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_57_filter_all_print_true.html
# 268/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_56_filter_all_print_true.html
# 269/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_58_filter_all_print_true.html
# 270/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_236_filter_all_print_true.html
# 271/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_235_filter_all_print_true.html
# 272/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_14_filter_all_print_true.html
# 273/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_240_filter_all_print_true.html
# 274/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_11_filter_all_print_true.html
# 275/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_12_filter_all_print_true.html
# 276/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_261_filter_all_print_true.html
# 277/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_232_filter_all_print_true.html
# 278/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_229_filter_all_print_true.html
# 279/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_88_filter_all_print_true.html
# 280/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_84_filter_all_print_true.html
# 281/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_85_filter_all_print_true.html
# 282/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_86_filter_all_print_true.html
# 283/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_87_filter_all_print_true.html
# 284/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_89_filter_all_print_true.html
# 285/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_299_filter_all_print_true.html
# 286/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_300_filter_all_print_true.html
# 287/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_230_filter_all_print_true.html
# 288/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_69_filter_all_print_true.html
# 289/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_68_filter_all_print_true.html
# 290/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_70_filter_all_print_true.html
# 291/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_183_filter_all_print_true.html
# 292/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_237_filter_all_print_true.html
# 293/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_238_filter_all_print_true.html
# 294/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_60_filter_all_print_true.html
# 295/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_61_filter_all_print_true.html
# 296/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_62_filter_all_print_true.html
# 297/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_63_filter_all_print_true.html
# 298/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_65_filter_all_print_true.html
# 299/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_59_filter_all_print_true.html
# 300/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_64_filter_all_print_true.html
# 301/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_239_filter_all_print_true.html
# 302/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_242_filter_all_print_true.html
# 303/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_241_filter_all_print_true.html
# 304/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_9_filter_all_print_true.html
# 305/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_10_filter_all_print_true.html
# 306/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_13_filter_all_print_true.html
# 307/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_243_filter_all_print_true.html
# 308/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_7_filter_all_print_true.html
# 309/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_71_filter_all_print_true.html
# 310/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_72_filter_all_print_true.html
# 311/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_76_filter_all_print_true.html
# 312/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_77_filter_all_print_true.html
# 313/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_73_filter_all_print_true.html
# 314/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_74_filter_all_print_true.html
# 315/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_75_filter_all_print_true.html
# 316/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_184_filter_all_print_true.html
# 317/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_192_filter_all_print_true.html
# 318/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_193_filter_all_print_true.html
# 319/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_178_filter_all_print_true.html
# 320/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_177_filter_all_print_true.html
# 321/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_180_filter_all_print_true.html
# 322/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_197_filter_all_print_true.html
# 323/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_254_filter_all_print_true.html
# 324/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_195_filter_all_print_true.html
# 325/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_196_filter_all_print_true.html
# 326/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_257_filter_all_print_true.html
# 327/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_283_filter_all_print_true.html
# 328/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_190_filter_all_print_true.html
# 329/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_268_filter_all_print_true.html
# 330/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_127_filter_all_print_true.html
# 331/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_125_filter_all_print_true.html
# 332/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_130_filter_all_print_true.html
# 333/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_124_filter_all_print_true.html
# 334/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_126_filter_all_print_true.html
# 335/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_123_filter_all_print_true.html
# 336/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_191_filter_all_print_true.html
# 337/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_182_filter_all_print_true.html
# 338/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_181_filter_all_print_true.html
# 339/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_66_filter_all_print_true.html
# 340/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_40_filter_all_print_true.html
# 341/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_79_filter_all_print_true.html
# 342/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_91_filter_all_print_true.html
# 343/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_90_filter_all_print_true.html
# 344/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_96_filter_all_print_true.html
# 345/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_93_filter_all_print_true.html
# 346/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_101_filter_all_print_true.html
# 347/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_102_filter_all_print_true.html
# 348/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_94_filter_all_print_true.html
# 349/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_111_filter_all_print_true.html
# 350/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_112_filter_all_print_true.html
# 351/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_113_filter_all_print_true.html
# 352/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_115_filter_all_print_true.html
# 353/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_117_filter_all_print_true.html
# 354/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_114_filter_all_print_true.html
# 355/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_116_filter_all_print_true.html
# 356/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_118_filter_all_print_true.html
# 357/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_146_filter_all_print_true.html
# 358/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_145_filter_all_print_true.html
# 359/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_149_filter_all_print_true.html
# 360/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_154_filter_all_print_true.html
# 361/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_141_filter_all_print_true.html
# 362/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_144_filter_all_print_true.html
# 363/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_151_filter_all_print_true.html
# 364/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_260_filter_all_print_true.html
# 365/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_81_filter_all_print_true.html
# 366/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_83_filter_all_print_true.html
# 367/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_82_filter_all_print_true.html
# 368/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_80_filter_all_print_true.html
# 369/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_78_filter_all_print_true.html
# 370/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_175_filter_all_print_true.html
# 371/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_259_filter_all_print_true.html
# 372/372
# Файл уже существует: pages\mathb-ege_sdamgia_ru_test_category_id_258_filter_all_print_true.html

# %% [markdown]
# Ниже можно увидеть 10 случайных строк датасете с категориями.
#
# **Колонки датасета:**
# 1. **category** — Основная тематическая категория задач
#
# 2. **subcategory** — Подраздел внутри категории с более узкой тематикой
#
# 3. **link** — Относительный URL-путь к странице с задачами данной подкатегории
#
# 4. **count** — Количество задач в данной подкатегории
#
# 5. **profile** — Уровень сложности: "basic" (базовый уровень ЕГЭ) или "profile" (профильный уровень ЕГЭ)

# %%
all_df.sample(10)
# Out:
#                                               category  \
# 94                            Стереометрическая задача
# 124                            Планиметрическая задача
# 253                                        Планиметрия
# 78                                           Уравнения
# 282                                   Текстовые задачи
# 245                            Прикладная стереометрия
# 15                                        Стереометрия
# 264                                         Вычисления
# 214                        Размеры и единицы измерения
# 368  Задания Д18. Наибольшее и наименьшее значение ...
#
#                                            subcategory  \
# 94                  Угол между скрещивающимися прямыми
# 124            Вписанные окружности и четырехугольники
# 253                     Четырёхугольники и их элементы
# 78   Тригонометрические уравнения, разложение на мн...
# 282                        Задачи на совместную работу
# 245                                                Куб
# 15                                              Призма
# 264                   Действия с обыкновенными дробями
# 214                            Единицы измерения массы
# 368            Исследование тригонометрических функций
#
#                                  link  count  profile
# 94   /test?category_id=285&filter=all     27  profile
# 124  /test?category_id=279&filter=all     36  profile
# 253  /test?category_id=288&filter=all     22    basic
# 78   /test?category_id=291&filter=all     61  profile
# 282   /test?category_id=87&filter=all     27    basic
# 245  /test?category_id=249&filter=all      3    basic
# 15   /test?category_id=178&filter=all     52  profile
# 264   /test?category_id=55&filter=all     28    basic
# 214  /test?category_id=244&filter=all     10    basic
# 368   /test?category_id=78&filter=all     29    basic

# %% [markdown]
# Для автоматического распознавания математических формул в изображениях и преобразования их в LaTeX-формат я использовала специализированный инструмент Surya OCR (https://github.com/datalab-to/surya), оптимизированный для работы с математическими обозначениями. Вывода здесь нет, так как я запускала его на сервере с GPU.

# %%
# !surya_latex_ocr ./images/tex/

# %% [markdown]
# Код ниже реализует пайплайн обработки сохраненных HTML-страниц с задачами: преобразует математические формулы из изображений в LaTeX-формат, извлекает текстовые условия и решения, собирает все в структурированный датасет. Код работает с двумя версиями текста — исходной русской и преобразованной с LaTeX-формулами.
#
# **Функции:**
#
# 1. `load_formulas(json_path)`
# **Аргументы:** `json_path` (str) - путь к JSON-файлу с формулами
# **Возвращает:** dict - словарь {имя файла: LaTeX-формула}
# **Описание:** Загружает предварительно извлеченные математические формулы из JSON, преобразует XML-формат формул в LaTeX (заменяет `<math>` теги на `$$`).
#
# 2. `normalize_russian_math_text(s)`
# **Аргументы:** `s` (str) - исходный текст
# **Возвращает:** str - очищенный текст
# **Описание:** Удаляет специальные Unicode-символы (мягкие переносы, тонкие пробелы, неразрывные пробелы), мешающие обработке.
#
# 3. `parse_paragraphs(block)`
# **Аргументы:** `block` - элемент BeautifulSoup
# **Возвращает:** str - нормализованный текст с переносами строк
# **Описание:** Извлекает текст из всех параграфов элемента, добавляет переносы строк и нормализует специальные символы.
#
# 4. `process_imgs(element, formulas, url)`
# **Аргументы:**
# - `element` - элемент BeautifulSoup
# - `formulas` (dict) - словарь LaTeX-формул
# - `url` (str) - исходный URL страницы
# **Возвращает:** tuple - (LaTeX-текст, русский текст, список путей к изображениям)
# **Описание:** Заменяет изображения формул на соответствующие LaTeX или на alt аргумен изображения, обычные изображения — на пути к файлам, возвращает две версии текста.
#
# 5. `parse_problem_html(path, url, formulas)`
# **Аргументы:**
# - `path` (str) - путь к HTML-файлу
# - `url` (str) - исходный URL
# - `formulas` (dict) - словарь LaTeX-формул
# **Возвращает:** pandas.DataFrame - таблица с задачами
# **Описание:** Парсит HTML-файл с задачами, извлекает условия и решения, заменяет формулы на LaTeX.
#
# 6. `parse_dataset(df, save_path="all_problems.csv")`
# **Аргументы:**
# - `df` (DataFrame) - таблица с метаданными и путями к HTML-файлам
# - `save_path` (str) - путь для сохранения итогового датасета (по умолчанию "all_problems.csv")
# **Возвращает:** pandas.DataFrame - объединенный датасет всех задач
# **Описание:** Основная функция обработки — последовательно парсит все HTML-файлы, объединяет результаты, проверяет соответствие количества задач, сохраняет итоговый датасет.

# %%
def load_formulas(json_path):
    """Загружает JSON с формулами и возвращает словарь key → latex_formula."""
    with open(json_path, "r", encoding="utf-8") as f:
        data = json.load(f)

    formulas = {}

    for key, value in data.items():
        if not value or "equation" not in value[0]:
            continue

        eq = value[0]["equation"]

        # Удаляем <math display="block"> и </math>, превращая в $$
        eq = re.sub(r'<math[^>]*>', '$$ ', eq)
        # убираем закрывающий тег
        eq = eq.replace('</math>', ' $$')

        formulas[key] = eq

    return formulas

def normalize_russian_math_text(s):
    # удалить мягкие переносы, тонкие пробелы, нулевые ширины
    chars = [
        "\u00AD",  # soft hyphen
        "\u200B",  # zero-width space
        "\u2060",  # word joiner
        "\xa0",    # non-breaking space
    ]
    for ch in chars:
        s = s.replace(ch, "")
    s = s.replace("\u202f", ' ')
    return s

def parse_paragraphs(block):
    for p in block.find_all("p"):
        # добавляем в конец каждого <p> символ переноса строки
        p.append("\n")
    return normalize_russian_math_text(block.get_text('', strip=False))

def process_imgs(element, formulas, url):
    imgs = []
    element_latex = element.__copy__()  # копия для LaTeX
    
    for img_rus, img_tex in zip(element.find_all("img"), element_latex.find_all("img")):
        is_tex = 'tex' in img_rus.get("class", "")
        src = img_rus.get("src")

        if src.startswith('/'):
            if url.startswith(domain[0]):
                src = domain[0] + src
            elif url.startswith(domain[1]):
                src = domain[1] + src
            else:
                print(f"ERROR: неизвестный домен url {url}")
        filename = safe_filename(src)
        img_path = os.path.join("images", f"{safe_filename(src)}.png")

        if is_tex:
            img_tex.replace_with(formulas[filename])

            alt = img_rus.get("alt", '').strip()
            img_rus.replace_with(alt)
        else:
            img_tex.replace_with(' ')
            img_rus.replace_with(' ')
            imgs.append(img_path)

    return parse_paragraphs(element_latex), parse_paragraphs(element), imgs

def parse_problem_html(path, url, formulas):
    with open(path, encoding="utf-8") as f:
        soup = BeautifulSoup(f.read(), "html")

    rows = []

    for block in soup.find_all("div", class_="prob_maindiv"):
        for element in block.find_all(check_not_visible):
            element.decompose()

        # id задачи (типо maindiv641019)
        body_id = block.get("id")
        num = re.sub(r"\D+", "", body_id)

        # тело условия
        body = block.find("div", class_="pbody")
        body_text, body_text_rus, imgs_b = process_imgs(body, formulas, url)

        # решение
        sol_block = block.find("div", class_="solution")
        sol_text, sol_text_rus, imgs_s = process_imgs(sol_block, formulas, url)

        rows.append({
            "id": num,
            "condition": body_text,
            "images_condition": imgs_b,
            "solution": sol_text,
            "condition_rus": body_text_rus,
            "solution_rus": sol_text_rus,
            "images_solution": imgs_s,
        })

    return pd.DataFrame(rows)

def parse_dataset(df, save_path="all_problems.csv"):
    """
    df: исходный DataFrame с колонками category, subcategory, link, count, profile, file
    save_path: куда сохранить итоговый объединённый датасет
    """
    all_dfs = []
    formulas = load_formulas("results.json")

    for idx, row in df.iterrows():
        html_file = row['file']
        print(f"[{idx+1}/{len(df)}] Парсим {html_file} {row['subcategory']}")
        base_url = BASE_URLS[row["profile"]]
        url = base_url + row["link"] + "?print=true"
        problems_df = parse_problem_html(html_file, formulas=formulas, url=url)

        # проверяем число задач
        expected_count = row.get("count")
        actual_count = len(problems_df)
        if expected_count is not None and actual_count != expected_count:
            print(f"[ERROR] {html_file}: ожидается {expected_count} задач, найдено {actual_count}")
            return None

        # добавляем данные из исходного датафрейма
        for col in ['category', 'subcategory', 'link', 'profile', 'file']:
            if col in row:
                problems_df[col] = row[col]

        all_dfs.append(problems_df)

    # объединяем все
    if all_dfs:
        final_df = pd.concat(all_dfs, ignore_index=True)
    else:
        final_df = pd.DataFrame()

    # сохраняем
    final_df.to_csv(save_path, index=False)
    print(f"[INFO] Итоговый датасет сохранён в {save_path}, всего задач: {len(final_df)}")
    
    return final_df

# %% [markdown]
# Создаю датасет задач и решений

# %%
df = parse_dataset(all_df)
# Out:
# [1/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_79_filter_all_print_true.html Решение прямоугольного треугольника
# [2/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_90_filter_all_print_true.html Решение равнобедренного треугольника
# [3/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_96_filter_all_print_true.html Треугольники общего вида
# [4/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_102_filter_all_print_true.html Параллелограммы
# [5/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_94_filter_all_print_true.html Трапеция
# [6/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_111_filter_all_print_true.html Центральные и вписанные углы
# [7/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_112_filter_all_print_true.html Касательная, хорда, секущая
# [8/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_113_filter_all_print_true.html Вписанные окружности
# [9/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_114_filter_all_print_true.html Описанные окружности
# [10/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_182_filter_all_print_true.html Векторы и операции с ними
# [11/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_192_filter_all_print_true.html Куб
# [12/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_193_filter_all_print_true.html Прямоугольный параллелепипед
# [13/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_180_filter_all_print_true.html Элементы составных многогранников
# [14/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_148_filter_all_print_true.html Площадь поверхности составного многогранника
# [15/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_140_filter_all_print_true.html Объем составного многогранника
# [16/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_178_filter_all_print_true.html Призма
# [17/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_177_filter_all_print_true.html Пирамида
# [18/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_197_filter_all_print_true.html Комбинации тел
# [19/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_194_filter_all_print_true.html Цилиндр
# [20/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_144_filter_all_print_true.html Конус
# [21/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_151_filter_all_print_true.html Шар
# [22/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_166_filter_all_print_true.html Классическое определение вероятности
# [23/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_185_filter_all_print_true.html Теоремы о вероятностях событий
# [24/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_265_filter_all_print_true.html Новые задания банка MathЕГЭ
# [25/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_14_filter_all_print_true.html Линейные, квадратные, кубические уравнения
# [26/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_9_filter_all_print_true.html Рациональные уравнения
# [27/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_10_filter_all_print_true.html Иррациональные уравнения
# [28/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_11_filter_all_print_true.html Показательные уравнения
# [29/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_12_filter_all_print_true.html Логарифмические уравнения
# [30/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_13_filter_all_print_true.html Тригонометрические уравнения
# [31/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_55_filter_all_print_true.html Преобразования числовых рациональных выражений
# [32/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_60_filter_all_print_true.html Преобразования алгебраических выражений и дробей
# [33/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_57_filter_all_print_true.html Вычисление значений степенных выражений
# [34/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_62_filter_all_print_true.html Действия со степенями
# [35/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_56_filter_all_print_true.html Преобразования числовых иррациональных выражений
# [36/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_61_filter_all_print_true.html Преобразования буквенных иррациональных выражений
# [37/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_58_filter_all_print_true.html Преобразования числовых логарифмических выражений
# [38/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_63_filter_all_print_true.html Преобразования буквенных логарифмических выражений
# [39/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_65_filter_all_print_true.html Вычисление значений тригонометрических выражений
# [40/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_59_filter_all_print_true.html Преобразования числовых тригонометрических выражений
# [41/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_64_filter_all_print_true.html Преобразования буквенных тригонометрических выражений
# [42/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_69_filter_all_print_true.html Физический смысл производной
# [43/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_68_filter_all_print_true.html Геометрический смысл производной, касательная
# [44/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_70_filter_all_print_true.html Применение производной к исследованию функций
# [45/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_183_filter_all_print_true.html Первообразная
# [46/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_71_filter_all_print_true.html Линейные уравнения и неравенства
# [47/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_72_filter_all_print_true.html Квадратные и степенные уравнения и неравенства
# [48/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_76_filter_all_print_true.html Рациональные уравнения и неравенства
# [49/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_77_filter_all_print_true.html Иррациональные уравнения и неравенства
# [50/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_73_filter_all_print_true.html Показательные уравнения и неравенства
# [51/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_74_filter_all_print_true.html Логарифмические уравнения и неравенства
# [52/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_75_filter_all_print_true.html Тригонометрические уравнения и неравенства
# [53/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_184_filter_all_print_true.html Разные задачи
# [54/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_88_filter_all_print_true.html Задачи на проценты, сплавы и смеси
# [55/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_84_filter_all_print_true.html Задачи на движение по прямой
# [56/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_85_filter_all_print_true.html Задачи на движение по окружности
# [57/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_86_filter_all_print_true.html Задачи на движение по воде
# [58/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_87_filter_all_print_true.html Задачи на совместную работу
# [59/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_89_filter_all_print_true.html Задачи на прогрессии
# [60/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_267_filter_all_print_true.html Линейные функции
# [61/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_294_filter_all_print_true.html Параболы
# [62/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_125_filter_all_print_true.html Гиперболы
# [63/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_122_filter_all_print_true.html Корни
# [64/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_272_filter_all_print_true.html Показательные и логарифмические функции
# [65/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_191_filter_all_print_true.html Тригонометрические функции
# [66/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_296_filter_all_print_true.html Комбинированные задачи
# [67/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_175_filter_all_print_true.html Исследование функций без помощи производной
# [68/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_81_filter_all_print_true.html Исследование степенных и иррациональных функций
# [69/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_83_filter_all_print_true.html Исследование частных
# [70/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_82_filter_all_print_true.html Исследование произведений
# [71/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_80_filter_all_print_true.html Исследование показательных и логарифмических функций
# [72/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_78_filter_all_print_true.html Исследование тригонометрических функций
# [73/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_330_filter_all_print_true.html Показательные уравнения
# [74/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_290_filter_all_print_true.html Рациональные уравнения
# [75/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_275_filter_all_print_true.html Иррациональные уравнения
# [76/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_186_filter_all_print_true.html Логарифмические уравнения
# [77/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_167_filter_all_print_true.html Тригонометрические уравнения, сводимые к квадратным
# [78/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_302_filter_all_print_true.html Тригонометрические уравнения, сводимые к однородным
# [79/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_291_filter_all_print_true.html Тригонометрические уравнения, разложение на множители
# [80/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_202_filter_all_print_true.html Тригонометрические уравнения, исследование ОДЗ
# [81/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_306_filter_all_print_true.html Тригонометрические уравнения, разные задачи
# [82/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_201_filter_all_print_true.html Тригонометрия и иррациональности
# [83/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_303_filter_all_print_true.html Тригонометрия и логарифмы
# [84/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_304_filter_all_print_true.html Тригонометрия и показательные выражения
# [85/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_305_filter_all_print_true.html Другие уравнения смешанного типа
# [86/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_280_filter_all_print_true.html Расстояние между прямыми и плоскостями
# [87/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_281_filter_all_print_true.html Расстояние между точками, от точки до прямой
# [88/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_307_filter_all_print_true.html Расстояние от точки до плоскости
# [89/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_282_filter_all_print_true.html Сечения пирамид
# [90/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_308_filter_all_print_true.html Сечения призм
# [91/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_309_filter_all_print_true.html Сечения параллелепипедов
# [92/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_283_filter_all_print_true.html Угол между плоскостями
# [93/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_311_filter_all_print_true.html Угол между плоскостями граней многогранника
# [94/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_284_filter_all_print_true.html Угол между прямой и плоскостью
# [95/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_285_filter_all_print_true.html Угол между скрещивающимися прямыми
# [96/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_257_filter_all_print_true.html Объёмы многогранников
# [97/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_310_filter_all_print_true.html Сечения круглых тел
# [98/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_206_filter_all_print_true.html Круглые тела: цилиндр, конус, шар
# [99/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_331_filter_all_print_true.html Комбинации фигур
# [100/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_243_filter_all_print_true.html Неравенства, содержащие радикалы
# [101/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_242_filter_all_print_true.html Рациональные неравенства
# [102/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_237_filter_all_print_true.html Показательные неравенства
# [103/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_320_filter_all_print_true.html Неравенства рациональные относительно показательной функции
# [104/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_238_filter_all_print_true.html Логарифмические неравенства первой и второй степени
# [105/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_318_filter_all_print_true.html Неравенства рациональные относительно логарифмической функции
# [106/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_239_filter_all_print_true.html Неравенства с логарифмами по переменному основанию
# [107/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_313_filter_all_print_true.html Неравенства с логарифмами по переменному основанию, применение рационализации
# [108/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_319_filter_all_print_true.html Логарифмические неравенства, разные задачи
# [109/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_315_filter_all_print_true.html Показательные выражения и иррациональности
# [110/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_245_filter_all_print_true.html Логарифмы и показательные выражения
# [111/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_314_filter_all_print_true.html Логарифмы и иррациональности
# [112/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_316_filter_all_print_true.html Неравенства с тригонометрией
# [113/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_244_filter_all_print_true.html Неравенства с модулем
# [114/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_317_filter_all_print_true.html Другие неравенства смешанного типа
# [115/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_293_filter_all_print_true.html Вклады
# [116/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_292_filter_all_print_true.html Кредиты
# [117/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_247_filter_all_print_true.html Задачи на оптимальный выбор
# [118/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_221_filter_all_print_true.html Разные задачи
# [119/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_276_filter_all_print_true.html Треугольники и их свойства
# [120/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_321_filter_all_print_true.html Четырехугольники и их свойства
# [121/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_277_filter_all_print_true.html Окружности и системы окружностей
# [122/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_278_filter_all_print_true.html Вписанные окружности и треугольники
# [123/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_322_filter_all_print_true.html Описанные окружности и треугольники
# [124/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_323_filter_all_print_true.html Окружности и треугольники, разные задачи
# [125/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_279_filter_all_print_true.html Вписанные окружности и четырехугольники
# [126/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_325_filter_all_print_true.html Описанные окружности и четырехугольники
# [127/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_326_filter_all_print_true.html Окружности и четырехугольники, разные задачи
# [128/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_324_filter_all_print_true.html Разные задачи о многоугольниках
# [129/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_171_filter_all_print_true.html Уравнения с параметром
# [130/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_328_filter_all_print_true.html Уравнения с параметром, содержащие модуль
# [131/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_327_filter_all_print_true.html Уравнения с параметром, содержащие радикалы
# [132/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_270_filter_all_print_true.html Неравенства с параметром
# [133/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_268_filter_all_print_true.html Системы с параметром
# [134/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_207_filter_all_print_true.html Расположение корней квадратного трехчлена
# [135/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_273_filter_all_print_true.html Использование симметрий
# [136/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_208_filter_all_print_true.html Использование монотонности, оценок
# [137/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_274_filter_all_print_true.html Аналитическое решение уравнений и неравенств
# [138/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_329_filter_all_print_true.html Аналитическое решение систем
# [139/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_271_filter_all_print_true.html Координаты (x, a)
# [140/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_266_filter_all_print_true.html Уравнение окружности
# [141/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_269_filter_all_print_true.html Расстояние между точками
# [142/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_235_filter_all_print_true.html Функции, зависящие от параметра
# [143/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_172_filter_all_print_true.html Числа и их свойства
# [144/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_217_filter_all_print_true.html Числовые наборы на карточках и досках
# [145/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_209_filter_all_print_true.html Последовательности и прогрессии
# [146/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_210_filter_all_print_true.html Сюжетные задачи: кино, театр, мотки верёвки
# [147/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_6_filter_all_print_true.html Определение величины по графику\
# [148/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_8_filter_all_print_true.html Определение величины по диаграмме
# [149/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_7_filter_all_print_true.html Вычисление величин по графику или диаграмме
# [150/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_174_filter_all_print_true.html Вычисления
# [151/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_1_filter_all_print_true.html Округление с недостатком
# [152/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_2_filter_all_print_true.html Округление с избытком
# [153/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_249_filter_all_print_true.html Проценты
# [154/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_5_filter_all_print_true.html Проценты и округление
# [155/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_54_filter_all_print_true.html Выбор варианта из двух возможных
# [156/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_53_filter_all_print_true.html Выбор варианта из трех возможных
# [157/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_173_filter_all_print_true.html Выбор варианта из четырех возможных
# [158/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_252_filter_all_print_true.html Многоугольники: вычисление длин и углов
# [159/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_190_filter_all_print_true.html Многоугольники: вычисление площадей
# [160/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_123_filter_all_print_true.html Круг и его элементы
# [161/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_181_filter_all_print_true.html Координатная плоскость
# [162/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_120_filter_all_print_true.html Трeугольники
# [163/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_250_filter_all_print_true.html Треугольники
# [164/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_127_filter_all_print_true.html Прямоугольник
# [165/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_124_filter_all_print_true.html Трапеции
# [166/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_253_filter_all_print_true.html Четырехугольники
# [167/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_126_filter_all_print_true.html Многоугольник
# [168/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_254_filter_all_print_true.html Окружности
# [169/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_255_filter_all_print_true.html Координатная плоскость
# [170/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_256_filter_all_print_true.html Задачи, связанные с углами. Задачи на многоугольники и окружности
# [171/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_251_filter_all_print_true.html Задачи, связанные с углами. Применение тригонометрии
# [172/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_248_filter_all_print_true.html Тригонометрические уравнения и неравенства
# [173/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_295_filter_all_print_true.html Уравнения без пункта б)
# [174/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_203_filter_all_print_true.html Системы тригонометрических уравнений
# [175/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_219_filter_all_print_true.html Сложные тригонометрические уравнения
# [176/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_220_filter_all_print_true.html Сложные тригонометрические уравнения, исследование ОДЗ
# [177/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_218_filter_all_print_true.html Сложные уравнения смешанного типа
# [178/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_231_filter_all_print_true.html Круглые тела
# [179/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_230_filter_all_print_true.html Многогранники
# [180/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_297_filter_all_print_true.html Кусочно-линейная функция
# [181/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_298_filter_all_print_true.html Параболы
# [182/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_211_filter_all_print_true.html Гиперболы
# [183/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_299_filter_all_print_true.html Тригонометрические функции
# [184/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_169_filter_all_print_true.html Системы, содержащие логарифмическое неравенство
# [185/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_204_filter_all_print_true.html Рациональные, иррациональные, показательные неравенства
# [186/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_214_filter_all_print_true.html Системы с логарифмами по переменному основанию
# [187/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_246_filter_all_print_true.html Неравенства различных типов
# [188/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_223_filter_all_print_true.html Рациональные, иррациональные, показательные неравенства
# [189/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_224_filter_all_print_true.html Системы с логарифмами по переменному основанию
# [190/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_225_filter_all_print_true.html Системы, содержащие логарифмическое неравенство
# [191/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_205_filter_all_print_true.html Многоугольники и их свойства
# [192/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_170_filter_all_print_true.html Окружности и треугольники
# [193/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_215_filter_all_print_true.html Окружности и четырёхугольники
# [194/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_216_filter_all_print_true.html Окружности и системы окружностей
# [195/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_262_filter_all_print_true.html Комбинации фигур
# [196/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_260_filter_all_print_true.html Многоугольники
# [197/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_261_filter_all_print_true.html Окружности
# [198/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_259_filter_all_print_true.html Треугольники
# [199/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_232_filter_all_print_true.html Практические задачи
# [200/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_258_filter_all_print_true.html Уравнения с параметром
# [201/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_240_filter_all_print_true.html Неравенства с параметром
# [202/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_241_filter_all_print_true.html Системы с параметром
# [203/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_288_filter_all_print_true.html Последовательности и прогрессии
# [204/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_289_filter_all_print_true.html Сюжетные задачи: кино, театр, мотки верёвки
# [205/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_286_filter_all_print_true.html Числа и их свойства
# [206/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_287_filter_all_print_true.html Числовые наборы на карточках и досках
# [207/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_226_filter_all_print_true.html Последовательности и прогрессии
# [208/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_227_filter_all_print_true.html Сюжетные задачи
# [209/372] Парсим pages\math-ege_sdamgia_ru_test_category_id_228_filter_all_print_true.html Числа и их свойства
# [210/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_1_filter_all_print_true.html Округление с недостатком
# [211/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_2_filter_all_print_true.html Округление с избытком
# [212/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_174_filter_all_print_true.html Разные задачи
# [213/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_246_filter_all_print_true.html Единицы измерения времени
# [214/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_233_filter_all_print_true.html Единицы измерения длины
# [215/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_244_filter_all_print_true.html Единицы измерения массы
# [216/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_247_filter_all_print_true.html Единицы измерения объёма
# [217/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_245_filter_all_print_true.html Единицы измерения площади
# [218/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_248_filter_all_print_true.html Различные единицы измерения
# [219/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_6_filter_all_print_true.html Определение величины по графику
# [220/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_8_filter_all_print_true.html Определение величины по диаграмме
# [221/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_291_filter_all_print_true.html Формулы с большим числом переменных
# [222/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_290_filter_all_print_true.html Формулы с одной и двумя переменными
# [223/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_187_filter_all_print_true.html Формулы с тремя переменными
# [224/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_166_filter_all_print_true.html Классическое определение вероятности
# [225/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_185_filter_all_print_true.html Теоремы о вероятностях событий
# [226/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_231_filter_all_print_true.html Подбор комплекта или комбинации
# [227/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_54_filter_all_print_true.html Выбор варианта из двух возможных
# [228/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_53_filter_all_print_true.html Выбор варианта из трех возможных
# [229/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_173_filter_all_print_true.html Выбор варианта из четырех возможных
# [230/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_292_filter_all_print_true.html Анализ графиков функций
# [231/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_189_filter_all_print_true.html Скорость изменения величин
# [232/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_222_filter_all_print_true.html Анализ утверждений
# [233/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_255_filter_all_print_true.html Задачи на карте
# [234/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_234_filter_all_print_true.html План местности
# [235/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_284_filter_all_print_true.html Трапеция
# [236/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_286_filter_all_print_true.html Треугольник
# [237/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_285_filter_all_print_true.html Ромб
# [238/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_122_filter_all_print_true.html Произвольный четырехугольник
# [239/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_301_filter_all_print_true.html Разные задачи
# [240/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_295_filter_all_print_true.html Квадрат
# [241/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_296_filter_all_print_true.html Окружность
# [242/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_293_filter_all_print_true.html Трапеция
# [243/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_294_filter_all_print_true.html Треугольник
# [244/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_188_filter_all_print_true.html Прямоугольник
# [245/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_253_filter_all_print_true.html Многогранники: ребра, грани
# [246/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_249_filter_all_print_true.html Куб
# [247/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_250_filter_all_print_true.html Прямоугольный параллелепипед
# [248/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_251_filter_all_print_true.html Призма
# [249/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_252_filter_all_print_true.html Пирамида
# [250/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_148_filter_all_print_true.html Площадь поверхности составного многогранника
# [251/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_140_filter_all_print_true.html Объем составного многогранника
# [252/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_289_filter_all_print_true.html Круглые тела
# [253/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_120_filter_all_print_true.html Треугольники и их элементы
# [254/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_288_filter_all_print_true.html Четырёхугольники и их элементы
# [255/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_275_filter_all_print_true.html Многоугольники
# [256/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_287_filter_all_print_true.html Окружность
# [257/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_263_filter_all_print_true.html Параллелепипед
# [258/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_264_filter_all_print_true.html Призма
# [259/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_267_filter_all_print_true.html Пирамида
# [260/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_265_filter_all_print_true.html Цилиндр
# [261/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_266_filter_all_print_true.html Конус
# [262/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_262_filter_all_print_true.html Шар
# [263/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_297_filter_all_print_true.html Действия с десятичными дробями
# [264/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_298_filter_all_print_true.html Разные задачи
# [265/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_55_filter_all_print_true.html Действия с обыкновенными дробями
# [266/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_5_filter_all_print_true.html Проценты, округление
# [267/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_57_filter_all_print_true.html Действия со степенями
# [268/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_56_filter_all_print_true.html Преобразования числовых иррациональных выражений
# [269/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_58_filter_all_print_true.html Преобразования числовых логарифмических выражений
# [270/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_236_filter_all_print_true.html Вычисление значений тригонометрических выражений
# [271/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_235_filter_all_print_true.html Преобразования числовых тригонометрических выражений
# [272/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_14_filter_all_print_true.html Линейные, квадратные, кубические уравнения
# [273/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_240_filter_all_print_true.html Иррациональные уравнения
# [274/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_11_filter_all_print_true.html Показательные уравнения
# [275/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_12_filter_all_print_true.html Логарифмические уравнения
# [276/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_261_filter_all_print_true.html Решение неравенств
# [277/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_232_filter_all_print_true.html Числовые промежутки
# [278/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_229_filter_all_print_true.html Цифровая запись числа
# [279/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_88_filter_all_print_true.html Задачи на проценты, сплавы и смеси
# [280/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_84_filter_all_print_true.html Задачи на движение по прямой
# [281/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_85_filter_all_print_true.html Задачи на движение по окружности
# [282/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_86_filter_all_print_true.html Задачи на движение по воде
# [283/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_87_filter_all_print_true.html Задачи на совместную работу
# [284/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_89_filter_all_print_true.html Задачи на прогрессии
# [285/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_299_filter_all_print_true.html Задачи о числах
# [286/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_300_filter_all_print_true.html Планиметрия
# [287/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_230_filter_all_print_true.html Текстовые задачи
# [288/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_69_filter_all_print_true.html Физический смысл производной
# [289/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_68_filter_all_print_true.html Геометрический смысл производной, касательная
# [290/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_70_filter_all_print_true.html Применение производной к исследованию функций
# [291/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_183_filter_all_print_true.html Первообразная
# [292/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_237_filter_all_print_true.html Преобразования числовых иррациональных выражений
# [293/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_238_filter_all_print_true.html Преобразования числовых логарифмических выражений
# [294/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_60_filter_all_print_true.html Преобразования алгебраических выражений и дробей
# [295/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_61_filter_all_print_true.html Преобразования буквенных иррациональных выражений
# [296/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_62_filter_all_print_true.html Преобразования буквенных показательных выражений
# [297/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_63_filter_all_print_true.html Преобразования буквенных логарифмических выражений
# [298/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_65_filter_all_print_true.html Вычисление значений тригонометрических выражений
# [299/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_59_filter_all_print_true.html Преобразования числовых тригонометрических выражений
# [300/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_64_filter_all_print_true.html Преобразования буквенных тригонометрических выражений
# [301/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_239_filter_all_print_true.html Линейные, квадратные, кубические уравнения
# [302/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_242_filter_all_print_true.html Логарифмические уравнения
# [303/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_241_filter_all_print_true.html Показательные уравнения
# [304/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_9_filter_all_print_true.html Рациональные уравнения
# [305/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_10_filter_all_print_true.html Иррациональные уравнения
# [306/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_13_filter_all_print_true.html Тригонометрические уравнения
# [307/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_243_filter_all_print_true.html Многоугольники
# [308/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_7_filter_all_print_true.html Вычисление величин по графику или диаграмме
# [309/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_71_filter_all_print_true.html Линейные уравнения и неравенства
# [310/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_72_filter_all_print_true.html Квадратичные и степенные уравнения и неравенства
# [311/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_76_filter_all_print_true.html Рациональные уравнения и неравенства
# [312/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_77_filter_all_print_true.html Иррациональные уравнения и неравенства
# [313/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_73_filter_all_print_true.html Показательные уравнения и неравенства
# [314/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_74_filter_all_print_true.html Логарифмические уравнения и неравенства
# [315/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_75_filter_all_print_true.html Тригонометрические уравнения и неравенства
# [316/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_184_filter_all_print_true.html Разные задачи
# [317/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_192_filter_all_print_true.html Куб
# [318/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_193_filter_all_print_true.html Прямоугольный параллелепипед
# [319/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_178_filter_all_print_true.html Призма
# [320/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_177_filter_all_print_true.html Пирамида
# [321/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_180_filter_all_print_true.html Элементы составных многогранников
# [322/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_197_filter_all_print_true.html Комбинации тел
# [323/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_254_filter_all_print_true.html Цилиндр
# [324/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_195_filter_all_print_true.html Конус
# [325/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_196_filter_all_print_true.html Шар
# [326/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_257_filter_all_print_true.html Скорость изменения величин
# [327/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_283_filter_all_print_true.html Произвольный четырехугольник
# [328/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_190_filter_all_print_true.html Задачи на квадратной решетке
# [329/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_268_filter_all_print_true.html Треугольник
# [330/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_127_filter_all_print_true.html Прямоугольник: длины и площади
# [331/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_125_filter_all_print_true.html Параллелограмм: длины и площади
# [332/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_130_filter_all_print_true.html Ромб: длины и площади
# [333/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_124_filter_all_print_true.html Трапеция: длины и площади
# [334/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_126_filter_all_print_true.html Многоугольник
# [335/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_123_filter_all_print_true.html Круг и его элементы
# [336/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_191_filter_all_print_true.html Вписанная и описанная окружности
# [337/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_182_filter_all_print_true.html Векторы
# [338/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_181_filter_all_print_true.html Координатная плоскость
# [339/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_66_filter_all_print_true.html Прямоугольный треугольник: вычисление углов
# [340/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_40_filter_all_print_true.html Прямоугольный треугольник: вычисление внешних углов
# [341/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_79_filter_all_print_true.html Прямоугольный треугольник: вычисление элементов
# [342/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_91_filter_all_print_true.html Равнобедренный треугольник: вычисление углов
# [343/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_90_filter_all_print_true.html Равнобедренный треугольник: вычисление элементов
# [344/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_96_filter_all_print_true.html Треугольники общего вида
# [345/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_93_filter_all_print_true.html Параллелограмм: углы
# [346/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_101_filter_all_print_true.html Прямоугольник: углы
# [347/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_102_filter_all_print_true.html Ромб: углы
# [348/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_94_filter_all_print_true.html Трапеция: углы
# [349/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_111_filter_all_print_true.html Центральные и вписанные углы
# [350/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_112_filter_all_print_true.html Касательная, хорда, секущая
# [351/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_113_filter_all_print_true.html Окружность, вписанная в треугольник
# [352/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_115_filter_all_print_true.html Окружность, вписанная в четырехугольник
# [353/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_117_filter_all_print_true.html Окружность, вписанная в многоугольник
# [354/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_114_filter_all_print_true.html Окружность, описанная вокруг треугольника
# [355/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_116_filter_all_print_true.html Окружность, описанная вокруг четырехугольника
# [356/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_118_filter_all_print_true.html Окружность, описанная вокруг многоугольника
# [357/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_146_filter_all_print_true.html Куб
# [358/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_145_filter_all_print_true.html Прямоугольный параллелепипед
# [359/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_149_filter_all_print_true.html Призма
# [360/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_154_filter_all_print_true.html Пирамида
# [361/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_141_filter_all_print_true.html Цилиндр
# [362/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_144_filter_all_print_true.html Конус
# [363/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_151_filter_all_print_true.html Шар
# [364/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_260_filter_all_print_true.html Числовая ось, числовые промежутки
# [365/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_81_filter_all_print_true.html Исследование степенных и иррациональных функций
# [366/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_83_filter_all_print_true.html Исследование частных
# [367/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_82_filter_all_print_true.html Исследование произведений
# [368/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_80_filter_all_print_true.html Исследование показательных и логарифмических функций
# [369/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_78_filter_all_print_true.html Исследование тригонометрических функций
# [370/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_175_filter_all_print_true.html Исследование функций без помощи производной
# [371/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_259_filter_all_print_true.html Цифровая запись числа
# [372/372] Парсим pages\mathb-ege_sdamgia_ru_test_category_id_258_filter_all_print_true.html Задачи на смекалку
# [INFO] Итоговый датасет сохранён в all_problems.csv, всего задач: 10196

# %% [markdown]
# Ниже можно увидеть 10 случайных колонок датасета с задачами.
#
# **Колонки:**
# 1. **id** — Уникальный числовой идентификатор задачи, извлеченный из HTML-элемента
# 2. **condition** — Условие задачи с математическими формулами в LaTeX-формате
# 3. **images_condition** — Список путей к обычным изображениям (не формулам) в условии задачи
# 4. **solution** — Решение задачи с математическими формулами в LaTeX-формате
# 5. **condition_rus** — Оригинальное условие задачи на русском языке (формулы как текст на русском)
# 6. **solution_rus** — Оригинальное решение задачи на русском языке
# 7. **images_solution** — Список путей к обычным изображениям в решении задачи
# 8. **category** — Основная тематическая категория
# 9. **subcategory** — Подраздел внутри категории
# 10. **link** — Относительный URL к странице с задачами этой подкатегории
# 11. **profile** — Уровень сложности: "basic" (базовый ЕГЭ) или "profile" (профильный ЕГЭ)
# 12. **file** — Локальный путь к сохраненному HTML-файлу с задачами подкатегории

# %%
df.sample(10)
# Out:
#            id                                          condition  \
# 10172  906049  Найдите точку максимума функции $$ y = 11^{6x-...
# 9997   695706   \nПлощадь основания конуса равна 18. Плоскост...
# 9309   918097   Основания трапеции равны 4 и 10. Найдите боль...
# 9099   945529   \nВ правильной треугольной пирамиде SABC с ве...
# 6435   643845  Две окружности пересекаются в точках A и B. Че...
# 3437   420536  Две окружности касаются внешним образом в точк...
# 5657   636366  В правильной треугольной пирамиде SABC сторона...
# 467    919344   Найдите объем правильной шестиугольной призмы...
# 1819   424242  а)  Решите уравнение $$ 2\sin 2x - \sin x \cdo...
# 3578   636710  Квадрат ABCD вписан в окружность. Хорда CE пер...
#
#                                         images_condition  \
# 10172                                                 []
# 9997   [images\mathb-ege_sdamgia_ru_get_file_id_13999...
# 9309   [images\mathb-ege_sdamgia_ru_get_file_id_11333...
# 9099   [images\mathb-ege_sdamgia_ru_get_file_id_11172...
# 6435                                                  []
# 3437                                                  []
# 5657                                                  []
# 467    [images\math-ege_sdamgia_ru_get_file_id_113235...
# 1819                                                  []
# 3578                                                  []
#
#                                                 solution  \
# 10172  \nРешение. Поскольку функция $$ y = 11^{x} $$ ...
# 9997   \nРешение. Сечение плоскостью, параллельной ос...
# 9309   \nРешение. Больший отрезок средней линии трапе...
# 9099   \nРешение. Отрезок OS высота треугольной пирам...
# 6435   \nРешение.   Пусть центры окружностей O1 и O2....
# 3437   \nРешение.  а)  Обозначим  центры  окружностей...
# 5657   \nРешение.  а)  Докажем, что прямая SC перпенд...
# 467    \nРешение. Объем прямой призмы равен V  =  Sh,...
# 1819   \nРешение. а)  Заметим, что \n\n$$ x = \begin{...
# 3578   \nРешение.  а)  В треугольниках CKD и CDE угол...
#
#                                            condition_rus  \
# 10172  Найдите точку максимума функции y=11 в степени...
# 9997    \nПлощадь основания конуса равна 18. Плоскост...
# 9309    Основания трапеции равны 4 и 10. Найдите боль...
# 9099    \nВ правильной треугольной пирамиде SABC с ве...
# 6435   Две окружности пересекаются в точках A и B. Че...
# 3437   Две окружности касаются внешним образом в точк...
# 5657   В правильной треугольной пирамиде SABC сторона...
# 467     Найдите объем правильной шестиугольной призмы...
# 1819   а)  Решите уравнение 2 синус 2x минус синус x ...
# 3578   Квадрат ABCD вписан в окружность. Хорда CE пер...
#
#                                             solution_rus  \
# 10172  \nРешение. Поскольку функция y=11 в степени x ...
# 9997   \nРешение. Сечение плоскостью, параллельной ос...
# 9309   \nРешение. Больший отрезок средней линии трапе...
# 9099   \nРешение. Отрезок OS высота треугольной пирам...
# 6435   \nРешение.   Пусть центры окружностей O1 и O2....
# 3437   \nРешение.  а)  Обозначим  центры  окружностей...
# 5657   \nРешение.  а)  Докажем, что прямая SC перпенд...
# 467    \nРешение. Объем прямой призмы равен V  =  Sh,...
# 1819   \nРешение. а)  Заметим, что \n\nx= система выр...
# 3578   \nРешение.  а)  В треугольниках CKD и CDE угол...
#
#                                          images_solution  \
# 10172                                                 []
# 9997                                                  []
# 9309                                                  []
# 9099                                                  []
# 6435   [images\math-ege_sdamgia_ru_get_file_id_30354....
# 3437   [images\math-ege_sdamgia_ru_get_file_id_148088...
# 5657   [images\math-ege_sdamgia_ru_get_file_id_41452....
# 467                                                   []
# 1819   [images\math-ege_sdamgia_ru_get_file_id_46175....
# 3578   [images\math-ege_sdamgia_ru_get_file_id_150092...
#
#                                                 category  \
# 10172  Задания Д18. Наибольшее и наименьшее значение ...
# 9997                 Задания Д16. Задачи по стереометрии
# 9309                            Задания Д15. Планиметрия
# 9099                           Задания Д13. Стереометрия
# 6435   Задания Д14 C4. Многоконфигурационная планимет...
# 3437                             Планиметрическая задача
# 5657                Задания Д10 C2. Сложная стереометрия
# 467                                         Стереометрия
# 1819                                           Уравнения
# 3578                             Планиметрическая задача
#
#                                        subcategory  \
# 10172  Исследование функций без помощи производной
# 9997                                         Конус
# 9309                     Трапеция: длины и площади
# 9099                                      Пирамида
# 6435              Окружности и системы окружностей
# 3437              Окружности и системы окружностей
# 5657                                  Круглые тела
# 467                                         Призма
# 1819              Тригонометрия и иррациональности
# 3578       Вписанные окружности и четырехугольники
#
#                                    link  profile  \
# 10172  /test?category_id=175&filter=all    basic
# 9997   /test?category_id=144&filter=all    basic
# 9309   /test?category_id=124&filter=all    basic
# 9099   /test?category_id=177&filter=all    basic
# 6435   /test?category_id=216&filter=all  profile
# 3437   /test?category_id=277&filter=all  profile
# 5657   /test?category_id=231&filter=all  profile
# 467    /test?category_id=178&filter=all  profile
# 1819   /test?category_id=201&filter=all  profile
# 3578   /test?category_id=279&filter=all  profile
#
#                                                     file
# 10172  pages\mathb-ege_sdamgia_ru_test_category_id_17...
# 9997   pages\mathb-ege_sdamgia_ru_test_category_id_14...
# 9309   pages\mathb-ege_sdamgia_ru_test_category_id_12...
# 9099   pages\mathb-ege_sdamgia_ru_test_category_id_17...
# 6435   pages\math-ege_sdamgia_ru_test_category_id_216...
# 3437   pages\math-ege_sdamgia_ru_test_category_id_277...
# 5657   pages\math-ege_sdamgia_ru_test_category_id_231...
# 467    pages\math-ege_sdamgia_ru_test_category_id_178...
# 1819   pages\math-ege_sdamgia_ru_test_category_id_201...
# 3578   pages\math-ege_sdamgia_ru_test_category_id_279...
